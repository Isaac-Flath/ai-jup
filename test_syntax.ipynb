# %%
import random

# %%
a = random.randint(0, 100)

# %% [markdown]
# What is the value of $`a`?

# %% [markdown]
# The value of the variable `a` is 51. This was generated by the `random.randint(0, 100)` function call in your previous code, which produced a random integer between 0 and 100 (inclusive), and in this case it generated 51.

# %%
a
# Out:
# 51
